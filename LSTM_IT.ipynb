# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('TCS 2024.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 60/60 [==============================] - 4s 7ms/step - loss: 0.0569
# Epoch 2/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 3/50
# 60/60 [==============================] - 0s 7ms/step - loss: 4.1912e-04
# Epoch 4/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.3180e-04
# Epoch 5/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.6548e-04
# Epoch 6/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.9894e-04
# Epoch 7/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.4980e-04
# Epoch 8/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0770e-04
# Epoch 9/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.0336e-05
# Epoch 10/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.0137e-05
# Epoch 11/50
# 60/60 [==============================] - 0s 7ms/step - loss: 4.7830e-05
# Epoch 12/50
# 60/60 [==============================] - 0s 7ms/step - loss: 4.1702e-05
# Epoch 13/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.8476e-05
# Epoch 14/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.5098e-05
# Epoch 15/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.4232e-05
# Epoch 16/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3577e-05
# Epoch 17/50
# 60/60 [==============================] - 1s 8ms/step - loss: 3.4027e-05
# Epoch 18/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.4769e-05
# Epoch 19/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3412e-05
# Epoch 20/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.2604e-05
# Epoch 21/50
# 60/60 [==============================] - 1s 9ms/step - loss: 3.4496e-05
# Epoch 22/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.2534e-05
# Epoch 23/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1901e-05
# Epoch 24/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3634e-05
# Epoch 25/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.3339e-05
# Epoch 26/50
# 60/60 [==============================] - 1s 8ms/step - loss: 3.1754e-05
# Epoch 27/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1506e-05
# Epoch 28/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.1597e-05
# Epoch 29/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.2143e-05
# Epoch 30/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3559e-05
# Epoch 31/50
# 60/60 [==============================] - 1s 9ms/step - loss: 3.2420e-05
# Epoch 32/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.2015e-05
# Epoch 33/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.2161e-05
# Epoch 34/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1411e-05
# Epoch 35/50
# 60/60 [==============================] - 0s 8ms/step - loss: 3.3918e-05
# Epoch 36/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1808e-05
# Epoch 37/50
# 60/60 [==============================] - 0s 8ms/step - loss: 3.1426e-05
# Epoch 38/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.1410e-05
# Epoch 39/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1453e-05
# Epoch 40/50
# 60/60 [==============================] - 1s 14ms/step - loss: 3.1516e-05
# Epoch 41/50
# 60/60 [==============================] - 1s 10ms/step - loss: 3.2892e-05
# Epoch 42/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.1267e-05
# Epoch 43/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3177e-05
# Epoch 44/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3051e-05
# Epoch 45/50
# 60/60 [==============================] - 0s 8ms/step - loss: 3.3886e-05
# Epoch 46/50
# 60/60 [==============================] - 1s 13ms/step - loss: 3.7395e-05
# Epoch 47/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3734e-05
# Epoch 48/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3258e-05
# Epoch 49/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.2115e-05
# Epoch 50/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.1655e-05
# 60/60 [==============================] - 1s 5ms/step
# 15/15 [==============================] - 0s 4ms/step
# Train RMSE: 19.207407333964113
# Test RMSE: 28.744971826400125

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("TCS Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('INFOSYS 2024.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 60/60 [==============================] - 3s 13ms/step - loss: 0.0730
# Epoch 2/50
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0089
# Epoch 3/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.9871e-04
# Epoch 4/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.6550e-04
# Epoch 5/50
# 60/60 [==============================] - 0s 7ms/step - loss: 4.8607e-04
# Epoch 6/50
# 60/60 [==============================] - 0s 8ms/step - loss: 4.2718e-04
# Epoch 7/50
# 60/60 [==============================] - 1s 9ms/step - loss: 3.6476e-04
# Epoch 8/50
# 60/60 [==============================] - 0s 6ms/step - loss: 3.2355e-04
# Epoch 9/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.7096e-04
# Epoch 10/50
# 60/60 [==============================] - 0s 7ms/step - loss: 2.3240e-04
# Epoch 11/50
# 60/60 [==============================] - 0s 7ms/step - loss: 2.0405e-04
# Epoch 12/50
# 60/60 [==============================] - 0s 8ms/step - loss: 1.7895e-04
# Epoch 13/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.6289e-04
# Epoch 14/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.4527e-04
# Epoch 15/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.4050e-04
# Epoch 16/50
# 60/60 [==============================] - 0s 8ms/step - loss: 1.2976e-04
# Epoch 17/50
# 60/60 [==============================] - 1s 10ms/step - loss: 1.2796e-04
# Epoch 18/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.2275e-04
# Epoch 19/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.2061e-04
# Epoch 20/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.1740e-04
# Epoch 21/50
# 60/60 [==============================] - 0s 8ms/step - loss: 1.1719e-04
# Epoch 22/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.1265e-04
# Epoch 23/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.1283e-04
# Epoch 24/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.1142e-04
# Epoch 25/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0922e-04
# Epoch 26/50
# 60/60 [==============================] - 1s 9ms/step - loss: 1.0718e-04
# Epoch 27/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0409e-04
# Epoch 28/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0305e-04
# Epoch 29/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0338e-04
# Epoch 30/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0018e-04
# Epoch 31/50
# 60/60 [==============================] - 1s 10ms/step - loss: 9.9615e-05
# Epoch 32/50
# 60/60 [==============================] - 0s 6ms/step - loss: 9.8046e-05
# Epoch 33/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.4642e-05
# Epoch 34/50
# 60/60 [==============================] - 0s 6ms/step - loss: 9.4183e-05
# Epoch 35/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.6851e-05
# Epoch 36/50
# 60/60 [==============================] - 0s 8ms/step - loss: 9.1387e-05
# Epoch 37/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.8127e-05
# Epoch 38/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.0078e-05
# Epoch 39/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.6651e-05
# Epoch 40/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.4722e-05
# Epoch 41/50
# 60/60 [==============================] - 0s 8ms/step - loss: 9.0707e-05
# Epoch 42/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.8741e-05
# Epoch 43/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.5078e-05
# Epoch 44/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.9582e-05
# Epoch 45/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.5681e-05
# Epoch 46/50
# 60/60 [==============================] - 1s 9ms/step - loss: 8.0934e-05
# Epoch 47/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.7824e-05
# Epoch 48/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.0748e-05
# Epoch 49/50
# 60/60 [==============================] - 0s 6ms/step - loss: 7.3749e-05
# Epoch 50/50
# 60/60 [==============================] - 0s 6ms/step - loss: 7.4857e-05
# 60/60 [==============================] - 1s 5ms/step
# 15/15 [==============================] - 0s 5ms/step
# Train RMSE: 12.860421066214448
# Test RMSE: 14.323734341492719

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("INFOSYS Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('WIPRO 2024.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 60/60 [==============================] - 3s 14ms/step - loss: 0.0530
# Epoch 2/50
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0063
# Epoch 3/50
# 60/60 [==============================] - 0s 7ms/step - loss: 4.5749e-04
# Epoch 4/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.9544e-04
# Epoch 5/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3854e-04
# Epoch 6/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.9282e-04
# Epoch 7/50
# 60/60 [==============================] - 1s 10ms/step - loss: 2.3695e-04
# Epoch 8/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.9462e-04
# Epoch 9/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.5460e-04
# Epoch 10/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.1990e-04
# Epoch 11/50
# 60/60 [==============================] - 0s 6ms/step - loss: 9.8585e-05
# Epoch 12/50
# 60/60 [==============================] - 1s 10ms/step - loss: 8.0374e-05
# Epoch 13/50
# 60/60 [==============================] - 0s 8ms/step - loss: 7.0005e-05
# Epoch 14/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.4670e-05
# Epoch 15/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.0290e-05
# Epoch 16/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.8644e-05
# Epoch 17/50
# 60/60 [==============================] - 1s 8ms/step - loss: 5.8058e-05
# Epoch 18/50
# 60/60 [==============================] - 1s 11ms/step - loss: 5.7974e-05
# Epoch 19/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.9722e-05
# Epoch 20/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.7279e-05
# Epoch 21/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.9835e-05
# Epoch 22/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.9898e-05
# Epoch 23/50
# 60/60 [==============================] - 0s 8ms/step - loss: 5.9168e-05
# Epoch 24/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.9837e-05
# Epoch 25/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.7623e-05
# Epoch 26/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.0800e-05
# Epoch 27/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.0582e-05
# Epoch 28/50
# 60/60 [==============================] - 1s 13ms/step - loss: 6.0351e-05
# Epoch 29/50
# 60/60 [==============================] - 1s 11ms/step - loss: 5.8708e-05
# Epoch 30/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.8490e-05
# Epoch 31/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.7966e-05
# Epoch 32/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.9911e-05
# Epoch 33/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.7617e-05
# Epoch 34/50
# 60/60 [==============================] - 1s 9ms/step - loss: 6.1301e-05
# Epoch 35/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.0928e-05
# Epoch 36/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.7064e-05
# Epoch 37/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.4139e-05
# Epoch 38/50
# 60/60 [==============================] - 0s 7ms/step - loss: 7.0634e-05
# Epoch 39/50
# 60/60 [==============================] - 1s 11ms/step - loss: 6.5441e-05
# Epoch 40/50
# 60/60 [==============================] - 1s 12ms/step - loss: 6.1764e-05
# Epoch 41/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.7434e-05
# Epoch 42/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.0643e-05
# Epoch 43/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.1952e-05
# Epoch 44/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.8921e-05
# Epoch 45/50
# 60/60 [==============================] - 1s 8ms/step - loss: 6.0016e-05
# Epoch 46/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.3172e-05
# Epoch 47/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.9169e-05
# Epoch 48/50
# 60/60 [==============================] - 0s 6ms/step - loss: 6.0337e-05
# Epoch 49/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.9421e-05
# Epoch 50/50
# 60/60 [==============================] - 0s 8ms/step - loss: 5.9874e-05
# 60/60 [==============================] - 1s 2ms/step
# 15/15 [==============================] - 0s 3ms/step
# Train RMSE: 4.955496145164984
# Test RMSE: 5.257681001247719

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("WIPRO Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('TECHMAHINDRA 2024.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 60/60 [==============================] - 3s 13ms/step - loss: 0.0459
# Epoch 2/50
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0062
# Epoch 3/50
# 60/60 [==============================] - 1s 14ms/step - loss: 6.8549e-04
# Epoch 4/50
# 60/60 [==============================] - 1s 9ms/step - loss: 5.2554e-04
# Epoch 5/50
# 60/60 [==============================] - 0s 6ms/step - loss: 4.2673e-04
# Epoch 6/50
# 60/60 [==============================] - 0s 7ms/step - loss: 3.3725e-04
# Epoch 7/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.6390e-04
# Epoch 8/50
# 60/60 [==============================] - 0s 7ms/step - loss: 2.0170e-04
# Epoch 9/50
# 60/60 [==============================] - 1s 9ms/step - loss: 1.5971e-04
# Epoch 10/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.3373e-04
# Epoch 11/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.1422e-04
# Epoch 12/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0368e-04
# Epoch 13/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.1380e-05
# Epoch 14/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.9241e-05
# Epoch 15/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.7862e-05
# Epoch 16/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.6630e-05
# Epoch 17/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.4850e-05
# Epoch 18/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.5149e-05
# Epoch 19/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.4467e-05
# Epoch 20/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.4215e-05
# Epoch 21/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.2308e-05
# Epoch 22/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.3292e-05
# Epoch 23/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.4410e-05
# Epoch 24/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.3807e-05
# Epoch 25/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.4878e-05
# Epoch 26/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.6216e-05
# Epoch 27/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.7090e-05
# Epoch 28/50
# 60/60 [==============================] - 1s 10ms/step - loss: 8.5575e-05
# Epoch 29/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.6796e-05
# Epoch 30/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.8498e-05
# Epoch 31/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.1914e-05
# Epoch 32/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.9371e-05
# Epoch 33/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.5927e-05
# Epoch 34/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.6192e-05
# Epoch 35/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.5181e-05
# Epoch 36/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.3851e-05
# Epoch 37/50
# 60/60 [==============================] - 0s 6ms/step - loss: 8.8868e-05
# Epoch 38/50
# 60/60 [==============================] - 1s 9ms/step - loss: 8.5550e-05
# Epoch 39/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.6563e-05
# Epoch 40/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.8644e-05
# Epoch 41/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.7099e-05
# Epoch 42/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.5866e-05
# Epoch 43/50
# 60/60 [==============================] - 1s 10ms/step - loss: 8.8299e-05
# Epoch 44/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.7670e-05
# Epoch 45/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.4242e-05
# Epoch 46/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.3718e-05
# Epoch 47/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.3096e-05
# Epoch 48/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.3628e-05
# Epoch 49/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.1916e-05
# Epoch 50/50
# 60/60 [==============================] - 0s 7ms/step - loss: 8.5848e-05
# 60/60 [==============================] - 1s 3ms/step
# 15/15 [==============================] - 0s 5ms/step
# Train RMSE: 13.055924958028069
# Test RMSE: 13.27708732048565

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("Tech Mahindra Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('HCLTECH 2024.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 60/60 [==============================] - 3s 13ms/step - loss: 0.0319
# Epoch 2/50
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0050
# Epoch 3/50
# 60/60 [==============================] - 0s 6ms/step - loss: 2.7107e-04
# Epoch 4/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.9678e-04
# Epoch 5/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.7138e-04
# Epoch 6/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.5363e-04
# Epoch 7/50
# 60/60 [==============================] - 1s 11ms/step - loss: 1.3900e-04
# Epoch 8/50
# 60/60 [==============================] - 0s 6ms/step - loss: 1.2522e-04
# Epoch 9/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.1209e-04
# Epoch 10/50
# 60/60 [==============================] - 0s 7ms/step - loss: 1.0063e-04
# Epoch 11/50
# 60/60 [==============================] - 0s 7ms/step - loss: 9.3985e-05
# Epoch 12/50
# 60/60 [==============================] - 0s 8ms/step - loss: 8.4829e-05
# Epoch 13/50
# 60/60 [==============================] - 0s 7ms/step - loss: 7.3979e-05
# Epoch 14/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.8367e-05
# Epoch 15/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.4424e-05
# Epoch 16/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.0228e-05
# Epoch 17/50
# 60/60 [==============================] - 1s 9ms/step - loss: 5.7675e-05
# Epoch 18/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.5401e-05
# Epoch 19/50
# 60/60 [==============================] - 0s 7ms/step - loss: 6.0522e-05
# Epoch 20/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.5487e-05
# Epoch 21/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.5895e-05
# Epoch 22/50
# 60/60 [==============================] - 0s 8ms/step - loss: 5.3122e-05
# Epoch 23/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2929e-05
# Epoch 24/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.3432e-05
# Epoch 25/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.1007e-05
# Epoch 26/50
# 60/60 [==============================] - 0s 8ms/step - loss: 5.3597e-05
# Epoch 27/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.2671e-05
# Epoch 28/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2179e-05
# Epoch 29/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.1105e-05
# Epoch 30/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.2948e-05
# Epoch 31/50
# 60/60 [==============================] - 1s 9ms/step - loss: 5.1383e-05
# Epoch 32/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.7019e-05
# Epoch 33/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2425e-05
# Epoch 34/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.0826e-05
# Epoch 35/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.3141e-05
# Epoch 36/50
# 60/60 [==============================] - 1s 10ms/step - loss: 5.2131e-05
# Epoch 37/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2797e-05
# Epoch 38/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2689e-05
# Epoch 39/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.3576e-05
# Epoch 40/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.3369e-05
# Epoch 41/50
# 60/60 [==============================] - 1s 9ms/step - loss: 5.1240e-05
# Epoch 42/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.0862e-05
# Epoch 43/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.0423e-05
# Epoch 44/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.3630e-05
# Epoch 45/50
# 60/60 [==============================] - 1s 8ms/step - loss: 5.1898e-05
# Epoch 46/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.0639e-05
# Epoch 47/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.2490e-05
# Epoch 48/50
# 60/60 [==============================] - 0s 6ms/step - loss: 5.4109e-05
# Epoch 49/50
# 60/60 [==============================] - 0s 7ms/step - loss: 5.3819e-05
# Epoch 50/50
# 60/60 [==============================] - 0s 8ms/step - loss: 5.2858e-05
# 60/60 [==============================] - 1s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# Train RMSE: 9.711383557885277
# Test RMSE: 15.187733674481818

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("HCL Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()
