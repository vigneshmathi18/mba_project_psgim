# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('BAJAJ-AUTO.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 61/61 [==============================] - 6s 12ms/step - loss: 0.0031
# Epoch 2/50
# 61/61 [==============================] - 1s 9ms/step - loss: 8.1945e-04
# Epoch 3/50
# 61/61 [==============================] - 0s 8ms/step - loss: 3.6183e-05
# Epoch 4/50
# 61/61 [==============================] - 0s 8ms/step - loss: 9.3611e-06
# Epoch 5/50
# 61/61 [==============================] - 0s 8ms/step - loss: 9.2882e-06
# Epoch 6/50
# 61/61 [==============================] - 0s 8ms/step - loss: 9.2754e-06
# Epoch 7/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.2372e-06
# Epoch 8/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.0600e-06
# Epoch 9/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.0962e-06
# Epoch 10/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.6368e-06
# Epoch 11/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.7931e-06
# Epoch 12/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.8066e-06
# Epoch 13/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.8528e-06
# Epoch 14/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.9123e-06
# Epoch 15/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.1760e-06
# Epoch 16/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.3217e-06
# Epoch 17/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.9328e-06
# Epoch 18/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.4570e-06
# Epoch 19/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.4719e-06
# Epoch 20/50
# 61/61 [==============================] - 1s 9ms/step - loss: 8.0444e-06
# Epoch 21/50
# 61/61 [==============================] - 1s 8ms/step - loss: 8.1871e-06
# Epoch 22/50
# 61/61 [==============================] - 1s 8ms/step - loss: 8.1324e-06
# Epoch 23/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.4610e-06
# Epoch 24/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.0597e-06
# Epoch 25/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.0376e-05
# Epoch 26/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.9184e-06
# Epoch 27/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.8962e-06
# Epoch 28/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.7003e-06
# Epoch 29/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.6198e-06
# Epoch 30/50
# 61/61 [==============================] - 1s 9ms/step - loss: 8.4990e-06
# Epoch 31/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.4689e-06
# Epoch 32/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.5035e-06
# Epoch 33/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.7835e-06
# Epoch 34/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.1154e-06
# Epoch 35/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.4905e-06
# Epoch 36/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.5848e-06
# Epoch 37/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.6759e-06
# Epoch 38/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.3524e-06
# Epoch 39/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.0840e-06
# Epoch 40/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.3219e-06
# Epoch 41/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.5115e-06
# Epoch 42/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.9832e-06
# Epoch 43/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.6790e-06
# Epoch 44/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.3894e-06
# Epoch 45/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.7636e-06
# Epoch 46/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.5911e-06
# Epoch 47/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.0816e-06
# Epoch 48/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.4007e-06
# Epoch 49/50
# 61/61 [==============================] - 0s 8ms/step - loss: 6.7113e-06
# Epoch 50/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.1216e-06
# 61/61 [==============================] - 1s 4ms/step
# 16/16 [==============================] - 0s 3ms/step
# Train RMSE: 34.69432221775332
# Test RMSE: 143.15021475087335

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("BAJAJ AUTO Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('TATAMOTORS.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 61/61 [==============================] - 3s 13ms/step - loss: 0.0272
# Epoch 2/50
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0029
# Epoch 3/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.3319e-04
# Epoch 4/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.7669e-04
# Epoch 5/50
# 61/61 [==============================] - 1s 9ms/step - loss: 1.1079e-04
# Epoch 6/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.8721e-05
# Epoch 7/50
# 61/61 [==============================] - 0s 7ms/step - loss: 6.2901e-05
# Epoch 8/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3879e-05
# Epoch 9/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.6559e-05
# Epoch 10/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.1224e-05
# Epoch 11/50
# 61/61 [==============================] - 0s 8ms/step - loss: 3.6342e-05
# Epoch 12/50
# 61/61 [==============================] - 0s 8ms/step - loss: 3.2490e-05
# Epoch 13/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.8967e-05
# Epoch 14/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.7622e-05
# Epoch 15/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.4035e-05
# Epoch 16/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.2781e-05
# Epoch 17/50
# 61/61 [==============================] - 0s 8ms/step - loss: 2.1580e-05
# Epoch 18/50
# 61/61 [==============================] - 1s 8ms/step - loss: 2.0623e-05
# Epoch 19/50
# 61/61 [==============================] - 1s 8ms/step - loss: 1.9987e-05
# Epoch 20/50
# 61/61 [==============================] - 1s 8ms/step - loss: 1.9987e-05
# Epoch 21/50
# 61/61 [==============================] - 0s 8ms/step - loss: 2.0104e-05
# Epoch 22/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8972e-05
# Epoch 23/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.9245e-05
# Epoch 24/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8818e-05
# Epoch 25/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.0434e-05
# Epoch 26/50
# 61/61 [==============================] - 1s 8ms/step - loss: 1.8440e-05
# Epoch 27/50
# 61/61 [==============================] - 1s 8ms/step - loss: 1.9536e-05
# Epoch 28/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8742e-05
# Epoch 29/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8425e-05
# Epoch 30/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8663e-05
# Epoch 31/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8514e-05
# Epoch 32/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8197e-05
# Epoch 33/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8039e-05
# Epoch 34/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8675e-05
# Epoch 35/50
# 61/61 [==============================] - 1s 8ms/step - loss: 1.9187e-05
# Epoch 36/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8139e-05
# Epoch 37/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8376e-05
# Epoch 38/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8857e-05
# Epoch 39/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.9202e-05
# Epoch 40/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8908e-05
# Epoch 41/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8815e-05
# Epoch 42/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8990e-05
# Epoch 43/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8643e-05
# Epoch 44/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.7823e-05
# Epoch 45/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8019e-05
# Epoch 46/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.7699e-05
# Epoch 47/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8095e-05
# Epoch 48/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.7573e-05
# Epoch 49/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.6934e-05
# Epoch 50/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8170e-05
# 61/61 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 0s 3ms/step
# Train RMSE: 5.22539474822785
# Test RMSE: 11.031766158631992

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("TATAMOTORS Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('MARUTI.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 61/61 [==============================] - 3s 13ms/step - loss: 0.0508
# Epoch 2/50
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0049
# Epoch 3/50
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0010
# Epoch 4/50
# 61/61 [==============================] - 1s 8ms/step - loss: 2.9698e-04
# Epoch 5/50
# 61/61 [==============================] - 1s 8ms/step - loss: 2.3594e-04
# Epoch 6/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.9055e-04
# Epoch 7/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.5818e-04
# Epoch 8/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.3069e-04
# Epoch 9/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.1005e-04
# Epoch 10/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.1522e-05
# Epoch 11/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.7922e-05
# Epoch 12/50
# 61/61 [==============================] - 0s 8ms/step - loss: 6.8841e-05
# Epoch 13/50
# 61/61 [==============================] - 0s 7ms/step - loss: 6.4147e-05
# Epoch 14/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.9430e-05
# Epoch 15/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.7596e-05
# Epoch 16/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.5463e-05
# Epoch 17/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.4877e-05
# Epoch 18/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.4089e-05
# Epoch 19/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.4316e-05
# Epoch 20/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3826e-05
# Epoch 21/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3936e-05
# Epoch 22/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3379e-05
# Epoch 23/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.3191e-05
# Epoch 24/50
# 61/61 [==============================] - 1s 9ms/step - loss: 5.4167e-05
# Epoch 25/50
# 61/61 [==============================] - 1s 8ms/step - loss: 5.3176e-05
# Epoch 26/50
# 61/61 [==============================] - 1s 8ms/step - loss: 5.2149e-05
# Epoch 27/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.3368e-05
# Epoch 28/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3448e-05
# Epoch 29/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.2397e-05
# Epoch 30/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3188e-05
# Epoch 31/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.4531e-05
# Epoch 32/50
# 61/61 [==============================] - 1s 8ms/step - loss: 5.4040e-05
# Epoch 33/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.5544e-05
# Epoch 34/50
# 61/61 [==============================] - 1s 9ms/step - loss: 5.3258e-05
# Epoch 35/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.0274e-05
# Epoch 36/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.2279e-05
# Epoch 37/50
# 61/61 [==============================] - 1s 8ms/step - loss: 5.4079e-05
# Epoch 38/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.2279e-05
# Epoch 39/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.2189e-05
# Epoch 40/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.9126e-05
# Epoch 41/50
# 61/61 [==============================] - 1s 8ms/step - loss: 5.1086e-05
# Epoch 42/50
# 61/61 [==============================] - 1s 9ms/step - loss: 4.8557e-05
# Epoch 43/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.0653e-05
# Epoch 44/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.9858e-05
# Epoch 45/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.0469e-05
# Epoch 46/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.9229e-05
# Epoch 47/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.1598e-05
# Epoch 48/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.9997e-05
# Epoch 49/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.7620e-05
# Epoch 50/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.8397e-05
# 61/61 [==============================] - 1s 4ms/step
# 16/16 [==============================] - 0s 3ms/step
# Train RMSE: 69.63015354594853
# Test RMSE: 112.90498935210476

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("MARUTI Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('M&M.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 61/61 [==============================] - 3s 13ms/step - loss: 0.0060
# Epoch 2/50
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 3/50
# 61/61 [==============================] - 0s 8ms/step - loss: 6.4417e-04
# Epoch 4/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.1079e-04
# Epoch 5/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.4545e-05
# Epoch 6/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.3113e-05
# Epoch 7/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.2674e-05
# Epoch 8/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.1034e-05
# Epoch 9/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.0739e-05
# Epoch 10/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.0972e-05
# Epoch 11/50
# 61/61 [==============================] - 1s 9ms/step - loss: 3.8744e-05
# Epoch 12/50
# 61/61 [==============================] - 1s 8ms/step - loss: 3.8076e-05
# Epoch 13/50
# 61/61 [==============================] - 1s 8ms/step - loss: 3.7595e-05
# Epoch 14/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.6773e-05
# Epoch 15/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.5866e-05
# Epoch 16/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.4609e-05
# Epoch 17/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.3766e-05
# Epoch 18/50
# 61/61 [==============================] - 0s 8ms/step - loss: 3.2782e-05
# Epoch 19/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.2580e-05
# Epoch 20/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.1369e-05
# Epoch 21/50
# 61/61 [==============================] - 0s 7ms/step - loss: 3.0498e-05
# Epoch 22/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.9286e-05
# Epoch 23/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.8977e-05
# Epoch 24/50
# 61/61 [==============================] - 0s 8ms/step - loss: 2.8971e-05
# Epoch 25/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.6614e-05
# Epoch 26/50
# 61/61 [==============================] - 0s 6ms/step - loss: 2.7547e-05
# Epoch 27/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.6091e-05
# Epoch 28/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.6452e-05
# Epoch 29/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.3337e-05
# Epoch 30/50
# 61/61 [==============================] - 0s 8ms/step - loss: 2.3273e-05
# Epoch 31/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.4128e-05
# Epoch 32/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.1849e-05
# Epoch 33/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.2013e-05
# Epoch 34/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.1306e-05
# Epoch 35/50
# 61/61 [==============================] - 0s 7ms/step - loss: 2.0050e-05
# Epoch 36/50
# 61/61 [==============================] - 1s 8ms/step - loss: 2.0419e-05
# Epoch 37/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.9514e-05
# Epoch 38/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8915e-05
# Epoch 39/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8692e-05
# Epoch 40/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8498e-05
# Epoch 41/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8113e-05
# Epoch 42/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8484e-05
# Epoch 43/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.8468e-05
# Epoch 44/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.9125e-05
# Epoch 45/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.7827e-05
# Epoch 46/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.8259e-05
# Epoch 47/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.9156e-05
# Epoch 48/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.9392e-05
# Epoch 49/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.9046e-05
# Epoch 50/50
# 61/61 [==============================] - 0s 8ms/step - loss: 1.7445e-05
# 61/61 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# Train RMSE: 12.001734565889882
# Test RMSE: 29.4971628135557

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("M&M Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (replace 'data.csv' with your actual file path)
data = pd.read_csv('HEROMOTOCO.csv')

# Ensure the 'Date' column is in datetime format and sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# Splitting the data into features (X) and target (y)
X = data[["Open", "High", "Low", "Volume"]].values
y = data["Close"].values

# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Splitting into training and testing sets (time series split)
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
date_train, date_test = data['Date'].iloc[:train_size], data['Date'].iloc[train_size:]

# Reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Predicting the stock prices
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform predictions and actual values
y_train_pred = scaler_y.inverse_transform(y_train_pred)
y_test_pred = scaler_y.inverse_transform(y_test_pred)
y_train_actual = scaler_y.inverse_transform(y_train)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate RMSE
train_rmse = sqrt(mean_squared_error(y_train_actual, y_train_pred))
test_rmse = sqrt(mean_squared_error(y_test_actual, y_test_pred))
print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Epoch 1/50
# 61/61 [==============================] - 4s 13ms/step - loss: 0.0313
# Epoch 2/50
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 3/50
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 4/50
# 61/61 [==============================] - 1s 8ms/step - loss: 3.4698e-04
# Epoch 5/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.4355e-04
# Epoch 6/50
# 61/61 [==============================] - 0s 7ms/step - loss: 1.1142e-04
# Epoch 7/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.9637e-05
# Epoch 8/50
# 61/61 [==============================] - 0s 7ms/step - loss: 9.4332e-05
# Epoch 9/50
# 61/61 [==============================] - 1s 8ms/step - loss: 8.8875e-05
# Epoch 10/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.5558e-05
# Epoch 11/50
# 61/61 [==============================] - 0s 8ms/step - loss: 8.2805e-05
# Epoch 12/50
# 61/61 [==============================] - 0s 7ms/step - loss: 8.0727e-05
# Epoch 13/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.7979e-05
# Epoch 14/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.4885e-05
# Epoch 15/50
# 61/61 [==============================] - 0s 7ms/step - loss: 7.3289e-05
# Epoch 16/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.1015e-05
# Epoch 17/50
# 61/61 [==============================] - 0s 8ms/step - loss: 7.2007e-05
# Epoch 18/50
# 61/61 [==============================] - 0s 8ms/step - loss: 6.3640e-05
# Epoch 19/50
# 61/61 [==============================] - 0s 7ms/step - loss: 6.1117e-05
# Epoch 20/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.9038e-05
# Epoch 21/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.8750e-05
# Epoch 22/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.6227e-05
# Epoch 23/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.8451e-05
# Epoch 24/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.2519e-05
# Epoch 25/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.3951e-05
# Epoch 26/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.0632e-05
# Epoch 27/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.3473e-05
# Epoch 28/50
# 61/61 [==============================] - 0s 7ms/step - loss: 5.1174e-05
# Epoch 29/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.9742e-05
# Epoch 30/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.8539e-05
# Epoch 31/50
# 61/61 [==============================] - 1s 8ms/step - loss: 4.7757e-05
# Epoch 32/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.9170e-05
# Epoch 33/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.1906e-05
# Epoch 34/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.7162e-05
# Epoch 35/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.6049e-05
# Epoch 36/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.6740e-05
# Epoch 37/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.5928e-05
# Epoch 38/50
# 61/61 [==============================] - 0s 8ms/step - loss: 5.6169e-05
# Epoch 39/50
# 61/61 [==============================] - 0s 8ms/step - loss: 6.0814e-05
# Epoch 40/50
# 61/61 [==============================] - 1s 8ms/step - loss: 4.5514e-05
# Epoch 41/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.4161e-05
# Epoch 42/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.4596e-05
# Epoch 43/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.5918e-05
# Epoch 44/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.4131e-05
# Epoch 45/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.3987e-05
# Epoch 46/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.3341e-05
# Epoch 47/50
# 61/61 [==============================] - 0s 8ms/step - loss: 4.2008e-05
# Epoch 48/50
# 61/61 [==============================] - 1s 8ms/step - loss: 4.3963e-05
# Epoch 49/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.2473e-05
# Epoch 50/50
# 61/61 [==============================] - 0s 7ms/step - loss: 4.3948e-05
# 61/61 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# Train RMSE: 36.37746990293835
# Test RMSE: 53.43913618122338

# %%
# Visualization of Actual vs Predicted with Date
plt.figure(figsize=(14, 8))

# Plot training data
plt.plot(date_train, y_train_actual, label="Actual Train Data", color='blue', alpha=0.7)
#plt.plot(date_train, y_train_pred, label="Predicted Train Data", color='cyan', alpha=0.7)

# Plot test data
plt.plot(date_test, y_test_actual, label="Actual Test Data", color='orange', alpha=0.7)
plt.plot(date_test, y_test_pred, label="Predicted Test Data", color='green', alpha=0.7)

# Formatting the plot
plt.title("HEROMOTOCO Stock Price Prediction by LSTM")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.grid()
plt.show()
